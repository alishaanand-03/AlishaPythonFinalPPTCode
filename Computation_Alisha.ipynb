# %%
import pandas as pd

# %%
from google.colab import files

# %%
uploaded = files.upload()

# %%
uploaded

# %%
import io

# %%
df=pd.read_csv(io.StringIO(uploaded['supermarket_sales - Sheet1.csv'].decode('utf-8')))

# %%
df
# Out:
#       Invoice ID Branch  ... gross income Rating
# 0    750-67-8428      A  ...      26.1415    9.1
# 1    226-31-3081      C  ...       3.8200    9.6
# 2    631-41-3108      A  ...      16.2155    7.4
# 3    123-19-1176      A  ...      23.2880    8.4
# 4    373-73-7910      A  ...      30.2085    5.3
# ..           ...    ...  ...          ...    ...
# 995  233-67-5758      C  ...       2.0175    6.2
# 996  303-96-2227      B  ...      48.6900    4.4
# 997  727-02-1313      A  ...       1.5920    7.7
# 998  347-56-2442      A  ...       3.2910    4.1
# 999  849-09-3807      A  ...      30.9190    6.6
#
# [1000 rows x 17 columns]

# %%
import numpy as np

# %%
print(max(df.Rating))
# Out:
# 10.0

# %%
print(min(df.Rating))
# Out:
# 4.0

# %%
df.describe() //mean value is greater than the median value
# Out:
#          Unitprice     Quantity  ...  grossincome      Rating
# count  1000.000000  1000.000000  ...  1000.000000  1000.00000
# mean     55.672130     5.512000  ...    15.379369     6.97270
# std      26.494628     2.923765  ...    11.708825     1.71858
# min      10.080000     1.000000  ...     0.508500     4.00000
# 25%      32.875000     3.000000  ...     5.924875     5.50000
# 50%      55.230000     5.000000  ...    12.088000     7.00000
# 75%      77.935000     8.000000  ...    22.445250     8.50000
# max      99.960000    10.000000  ...    49.650000    10.00000
#
# [8 rows x 8 columns]

# %%
df.shape     //comprises of 1000 observations and 17 characteristics
# Out:
# (1000, 17)

# %%
df.info   //data has float and integer values
# Out:
# <bound method DataFrame.info of       Invoice ID Branch       City  ... grossmarginpercentage grossincome Rating
# 0    750-67-8428      A     Yangon  ...              4.761905     26.1415    9.1
# 1    226-31-3081      C  Naypyitaw  ...              4.761905      3.8200    9.6
# 2    631-41-3108      A     Yangon  ...              4.761905     16.2155    7.4
# 3    123-19-1176      A     Yangon  ...              4.761905     23.2880    8.4
# 4    373-73-7910      A     Yangon  ...              4.761905     30.2085    5.3
# ..           ...    ...        ...  ...                   ...         ...    ...
# 995  233-67-5758      C  Naypyitaw  ...              4.761905      2.0175    6.2
# 996  303-96-2227      B   Mandalay  ...              4.761905     48.6900    4.4
# 997  727-02-1313      A     Yangon  ...              4.761905      1.5920    7.7
# 998  347-56-2442      A     Yangon  ...              4.761905      3.2910    4.1
# ...

# %%
df=df.drop(['Gender'],axis=1)  //to drop gender as it is not needed for now

# %%
df
# Out:
#       Invoice ID Branch       City  ... grossmarginpercentage grossincome  Rating
# 0    750-67-8428      A     Yangon  ...              4.761905     26.1415     9.1
# 1    226-31-3081      C  Naypyitaw  ...              4.761905      3.8200     9.6
# 2    631-41-3108      A     Yangon  ...              4.761905     16.2155     7.4
# 3    123-19-1176      A     Yangon  ...              4.761905     23.2880     8.4
# 4    373-73-7910      A     Yangon  ...              4.761905     30.2085     5.3
# ..           ...    ...        ...  ...                   ...         ...     ...
# 995  233-67-5758      C  Naypyitaw  ...              4.761905      2.0175     6.2
# 996  303-96-2227      B   Mandalay  ...              4.761905     48.6900     4.4
# 997  727-02-1313      A     Yangon  ...              4.761905      1.5920     7.7
# 998  347-56-2442      A     Yangon  ...              4.761905      3.2910     4.1
# ...

# %%
df = df.drop_duplicates() //it has dropped the duplicate values
df
# Out:
#       Invoice ID Branch       City  ... grossmarginpercentage grossincome  Rating
# 0    750-67-8428      A     Yangon  ...              4.761905     26.1415     9.1
# 1    226-31-3081      C  Naypyitaw  ...              4.761905      3.8200     9.6
# 2    631-41-3108      A     Yangon  ...              4.761905     16.2155     7.4
# 3    123-19-1176      A     Yangon  ...              4.761905     23.2880     8.4
# 4    373-73-7910      A     Yangon  ...              4.761905     30.2085     5.3
# ..           ...    ...        ...  ...                   ...         ...     ...
# 995  233-67-5758      C  Naypyitaw  ...              4.761905      2.0175     6.2
# 996  303-96-2227      B   Mandalay  ...              4.761905     48.6900     4.4
# 997  727-02-1313      A     Yangon  ...              4.761905      1.5920     7.7
# 998  347-56-2442      A     Yangon  ...              4.761905      3.2910     4.1
# ...

# %%
list(set(df.dtypes.tolist()))
# Out:
# [dtype('int64'), dtype('O'), dtype('float64')]

# %%
pip install numpy

# %%
import numpy as np

# %%
newCogs=np.array(df.Unitprice)*np.array(df.Quantity) //cogs=Unitprice*Quantity
print(newCogs)
# Out:
# [522.83 106.96 324.31 465.76 604.17 597.73 413.04 735.6   72.52 164.52
#   57.92 102.04 234.75 431.9  713.8  562.32 482.51 435.66 164.01  80.6
#  430.2  263.94  66.4  172.8  265.89 420.72  33.52 175.34 441.8  224.01
#  470.65 702.63 670.24 193.16 397.68  68.12 313.1  547.92 439.36 240.96
#   86.72 112.22 414.72 789.6   30.74 375.84 510.21 180.09 113.58 826.3
#  639.8  222.95  71.48  15.43  32.32 687.84  88.68 716.8  723.5  183.66
#   74.22 334.38 495.63 158.1  302.96 158.7   66.94 585.66 787.7   18.33
#  894.8  621.2  145.56 455.46 672.03 416.5  441.36 180.09 783.1  101.9
#  595.14 290.04 154.   321.44 244.55 581.42 382.6  345.66  42.47 461.94
#  189.52 448.6  153.86 579.24  89.75  97.16 878.7   74.7  158.25 496.2
#   48.71 706.95 207.63 349.56 212.45 886.7  164.28 372.78 305.82 819.7
#   32.98 294.63 509.88 522.63 727.11  81.06 109.7   51.36 109.6  106.88
#  796.48 399.84 899.64 511.28 451.76 655.83 161.25 285.57 548.32 812.52
# ...

# %%
co=np.array(df.cogs) //from table
print(co)
# Out:
# [522.83  76.4  324.31 465.76 604.17 597.73 413.04 735.6   72.52 164.52
#   57.92 102.04 234.75 431.9  713.8  562.32 482.51 435.66 164.01  80.6
#  430.2  263.94  66.4  172.8  265.89 420.72  33.52 175.34 441.8  224.01
#  470.65 702.63 670.24 193.16 397.68  68.12 313.1  547.92 439.36 240.96
#   86.72 112.22 414.72 789.6   30.74 375.84 510.21 180.09 113.58 826.3
#  639.8  222.95  71.48  15.43  32.32 687.84  88.68 716.8  723.5  183.66
#   74.22 334.38 495.63 158.1  302.96 158.7   66.94 585.66 787.7   18.33
#  894.8  621.2  145.56 455.46 672.03 416.5  441.36 180.09 783.1  101.9
#  595.14 290.04 154.   321.44 244.55 581.42 382.6  345.66  42.47 461.94
#  189.52 448.6  153.86 579.24  89.75  97.16 878.7   74.7  158.25 496.2
#   48.71 706.95 207.63 349.56 212.45 886.7  164.28 372.78 305.82 819.7
#   32.98 294.63 509.88 522.63 727.11  81.06 109.7   51.36 109.6  106.88
#  796.48 399.84 899.64 511.28 451.76 655.83 161.25 285.57 548.32 812.52
# ...

# %%
totalgross=sum(np.array(df.grossincome))   //total gross income across products
print(totalgross)
# Out:
# 15379.369000000002
